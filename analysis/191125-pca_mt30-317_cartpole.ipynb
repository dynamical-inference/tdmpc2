# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

# Add parent directory to path for imports
sys.path.insert(0, "/home/hgf_hmgu/hgf_gib4562/tdmpc2/tdmpc2/")

from analysis.load_run_data import load_run_data
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
from itertools import combinations
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
import pickle
from tqdm import tqdm
from sklearn.linear_model import LinearRegression, Lasso, MultiTaskLasso, LassoCV, MultiTaskLassoCV

from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import LeaveOneGroupOut

from sklearn.metrics import r2_score

from analysis.utils import extract_variables
import pickle

# %%
from analysis.utils import fit_rastermap, plot_rastermap_with_rewards_actions
import pickle
import json
from pathlib import Path
import pandas as pd

# %%
def load_data(
    df_metadata,
    hinge_1_value=None,
    seed=None,
):
    """
    Load intervention data from directories matching the specified criteria.
    
    Parameters can be single values or lists. If a parameter is None, it matches all values.
    
    Returns:
        pd.DataFrame: DataFrame with config info and episode data
    """

    # Convert single values to lists for uniform handling
    def to_list(val):
        if val is None:
            return None
        return val if isinstance(val, list) else [val]

    hinge_1_value_list = to_list(hinge_1_value)
    seed_list = to_list(seed)

    # Filter configs based on criteria
    filtered_configs = []
    for idx, config in df_metadata.iterrows():
        # Check each criterion
        if hinge_1_value_list is not None and config.get(
                'config_hinge_1_value') not in hinge_1_value_list:
            continue
        if seed_list is not None and config.get('config_seed') not in seed_list:
            continue

        filtered_configs.append(config)

    print(f"Found {len(filtered_configs)} configurations")
    # Load episode data for each matching config
    results = []
    for config in tqdm(filtered_configs):
        directory = Path(config['directory'])
        episode_path = directory / "activations" / "episode_0000.pkl"

        if episode_path.exists():
            # Load the pickled episode data
            with open(episode_path, 'rb') as f:
                episode_data = pickle.load(f)

            # Unflatten the data structure
            episode_data = episode_data['data']
            for key, value in episode_data.items():

                if key == 'latent_states':
                    config[key] = value.squeeze()
                else:
                    config[key] = value

            results.append(config)

    return pd.DataFrame(results)

# %%
def flatten_dict(d, parent_key='', sep='_'):
    """
    Flatten a nested dictionary.
    
    Args:
        d: Dictionary to flatten
        parent_key: String to prepend to keys
        sep: Separator between nested keys
    
    Returns:
        Flattened dictionary
    """
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)


# Loop over all directories in the sweep logs
sweep_base_dir = Path(
    "/home/hgf_hmgu/hgf_gib4562/tdmpc2/logs/181125-initial_conditions_mt30-317M_sweep"
)

all_metadata = []
for sweep_dir in sweep_base_dir.iterdir():
    if sweep_dir.is_dir():
        metadata_path = sweep_dir / "activations" / "episode_0000_metadata.json"
        if metadata_path.exists():
            with open(metadata_path, 'r') as f:
                metadata = json.load(f)
                # Flatten the nested metadata dictionary
                flattened_metadata = flatten_dict(metadata)
                # Add the directory path
                flattened_metadata['directory'] = str(sweep_dir)
                all_metadata.append(flattened_metadata)

print(f"Found {len(all_metadata)} configurations")

# Create DataFrame from flattened metadata
df_metadata = pd.DataFrame(all_metadata)
# Out:
# Found 45 configurations

# %%
df_data = load_data(df_metadata)
# Out:
# Found 45 configurations
# 100%|██████████| 45/45 [00:00<00:00, 90.24it/s]

# %%
# Strip plot of total reward vs hinge_1_value using seaborn
plt.figure(figsize=(10, 6))
df_plot = pd.DataFrame({
    'hinge_1_value': df_metadata['config_hinge_1_value'],
    'total_reward': df_data['rewards'].apply(lambda x: x.sum())
})
sns.stripplot(data=df_plot, x='hinge_1_value', y='total_reward', alpha=0.6)
plt.xlabel('Hinge 1 Value')
plt.ylabel('Total Reward')
plt.title('Total Reward vs Initial Hinge 1 Value')
plt.grid(True, alpha=0.3)
plt.show()

# %%
latents_arr = np.concatenate(df_data['latent_states'], axis=0)
rewards_arr = np.concatenate(df_data['rewards'], axis=0)
actions_arr = np.concatenate(df_data['actions'], axis=0)
observations_arr = np.concatenate(df_data['observations'], axis=0)

print(latents_arr.shape, rewards_arr.shape, actions_arr.shape,
      observations_arr.shape)

print("Removing dimensions with zero entries")
latents_arr = latents_arr[:, (latents_arr != 0).any(axis=0)]
rewards_arr = rewards_arr[:, (rewards_arr != 0).any(axis=0)]
actions_arr = actions_arr[:, (actions_arr != 0).any(axis=0)]
observations_arr = observations_arr[:, (observations_arr != 0).any(axis=0)]
all_arrs = np.concatenate([observations_arr, rewards_arr, actions_arr], axis=1)

print(latents_arr.shape, rewards_arr.shape, actions_arr.shape,
      observations_arr.shape, all_arrs.shape)
# Out:
# (22500, 1376) (22500,) (22500, 6) (22500, 24)
# Removing dimensions with zero entries
# (22500, 1376) (22500, 1) (22500, 1) (22500, 5) (22500, 7)

# %% [markdown]
# ## Finding non-aligned spaces

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, FastICA, SparsePCA
from sklearn.preprocessing import StandardScaler


def analyze_latent_to_observation_mapping(Xs,
                                          Ys,
                                          method="pca",
                                          n_components=10):
    """
    observations: [T, D_obs]  -> e.g. DMControl proprioceptive states
    latents: [T, D_latent]    -> TD-MPC2 encoder outputs
    method: 'pca' or 'ica'
    obs_labels: optional list of observation names
    """
    # normalize latents for analysis
    #Z = StandardScaler().fit_transform(latents)
    #O = StandardScaler().fit_transform(observations)

    if method == "pca":
        model = PCA(n_components=n_components)
    elif method == "ica":
        model = FastICA(n_components=n_components, whiten="unit-variance")
    elif method == 'sparse_pca':
        model = SparsePCA(n_components=n_components, alpha=0.1)
    else:
        raise ValueError("method must be 'pca' or 'ica'")

    # Fit decomposition
    F = model.fit_transform(Xs)  # [T, n_components]
    comps = model.components_  # [n_components, D_latent]

    # Correlate each component with each observation variable
    corr_matrix = np.corrcoef(F.T, Ys.T)[:n_components, n_components:]

    # Get explained variance if available
    explained_variance = None
    if hasattr(model, 'explained_variance_ratio_'):
        explained_variance = model.explained_variance_ratio_
        print(f"Explained variance by component: {explained_variance}")
        print(f"Total explained variance: {explained_variance.sum():.3f}")

    return corr_matrix, comps, explained_variance, F


def plot_component_correlations(corr_matrix,
                                obs_labels=None,
                                title="Latent-Observation Map"):
    n_components, D_obs = corr_matrix.shape
    plt.figure(figsize=(12, 4))
    plt.imshow(corr_matrix, aspect='auto', cmap='coolwarm', vmin=-1, vmax=1)
    plt.colorbar(label='Correlation')
    plt.xlabel("Observation variables")
    plt.ylabel("Latent components")
    plt.title(title)
    if obs_labels:
        plt.xticks(range(D_obs), obs_labels, rotation=90)
    plt.tight_layout()
    plt.show()

# %%
all_arrs = np.concatenate([observations_arr, rewards_arr, actions_arr], axis=1)

corr_pca_all, comps_pca_all, exp_var_all, F_all = analyze_latent_to_observation_mapping(
    Xs=latents_arr,
    Ys=all_arrs,
    method="pca",
    n_components=10,
)

comps_pca_eps = []
for eps_idx, row in df_data.iterrows():

    latent_eps = row['latent_states']
    obs_eps = np.array(row['observations'])
    rew_eps = np.array(row['rewards'])
    act_eps = np.array(row['actions'])

    obs_eps = obs_eps[:, (obs_eps != 0).any(axis=0)]
    rew_eps = rew_eps[:, (rew_eps != 0).any(axis=0)]
    act_eps = act_eps[:, (act_eps != 0).any(axis=0)]
    all_eps = np.concatenate([obs_eps, rew_eps, act_eps], axis=1)

    corr_pca, comps_pca, exp_var, F = analyze_latent_to_observation_mapping(
        Xs=latent_eps,
        Ys=all_eps,
        method="pca",
        n_components=10,
    )
    comps_pca_eps.append(comps_pca)
# Out:
# Explained variance by component: [0.21029928 0.1743738  0.14541885 0.1014097  0.06745459 0.05590202
#  0.03842698 0.03778153 0.02381249 0.01964507]
# Total explained variance: 0.875
# Explained variance by component: [0.22425325 0.17467782 0.14291197 0.08271127 0.07024997 0.05813316
#  0.04278935 0.0385554  0.02883422 0.02029678]
# Total explained variance: 0.883
# Explained variance by component: [0.23101373 0.18112703 0.14568052 0.07286931 0.06948747 0.05996683
#  0.04245204 0.03650365 0.02869586 0.01989299]
# Total explained variance: 0.888
# Explained variance by component: [0.23456724 0.17299388 0.14696547 0.08921597 0.07539835 0.06018285
#  0.04266236 0.02819222 0.02671884 0.0164538 ]
# Total explained variance: 0.893
# Explained variance by component: [0.2329417  0.17499903 0.14591019 0.07540879 0.06862131 0.06096435
#  0.0422635  0.03706726 0.02614189 0.02067779]
# Total explained variance: 0.885
# Explained variance by component: [0.23329796 0.1778682  0.14392972 0.07541032 0.06899827 0.05959918
#  0.04222499 0.03685369 0.02836687 0.02062049]
# Total explained variance: 0.887
# Explained variance by component: [0.23761252 0.17258286 0.15856491 0.08159181 0.07688328 0.0536014
#  0.04420966 0.02775829 0.02313312 0.02033506]
# Total explained variance: 0.896
# Explained variance by component: [0.23105654 0.18001562 0.14583471 0.07379864 0.06994669 0.05903097
#  0.04327315 0.03659882 0.02820266 0.02028101]
# Total explained variance: 0.888
# Explained variance by component: [0.23483808 0.16733378 0.14002845 0.08231723 0.06823012 0.06195352
#  0.0444653  0.03434239 0.02500743 0.02034272]
# Total explained variance: 0.879
# Explained variance by component: [0.23663193 0.17676722 0.14292221 0.07451772 0.0690447  0.0596967
#  0.04252977 0.03631901 0.02848601 0.02014685]
# Total explained variance: 0.887
# Explained variance by component: [0.23042779 0.17729475 0.14329898 0.07917475 0.06872113 0.05809025
#  0.04284499 0.03807491 0.0285332  0.0203358 ]
# Total explained variance: 0.887
# Explained variance by component: [0.23765516 0.17086333 0.14070205 0.09231814 0.07701056 0.05877922
#  0.04534382 0.02893568 0.02711038 0.0179372 ]
# Total explained variance: 0.897
# Explained variance by component: [0.23548521 0.17714943 0.14460824 0.07417402 0.06851561 0.06054628
#  0.04258251 0.03686941 0.02738041 0.02040208]
# Total explained variance: 0.888
# Explained variance by component: [0.23484637 0.1775142  0.14550124 0.07392658 0.06912506 0.06054313
#  0.04178934 0.03723101 0.02743741 0.02040025]
# Total explained variance: 0.888
# Explained variance by component: [0.23875482 0.16466516 0.14861776 0.0891042  0.07494185 0.06006489
#  0.04353983 0.03014023 0.02684361 0.01701785]
# Total explained variance: 0.894
# Explained variance by component: [0.23406556 0.18085337 0.14624429 0.07146814 0.06850868 0.06031794
#  0.04277143 0.03557374 0.02754285 0.02019839]
# Total explained variance: 0.888
# Explained variance by component: [0.23137414 0.17788056 0.14371563 0.07187811 0.06758548 0.06005533
#  0.0422507  0.03655226 0.0274587  0.02095519]
# Total explained variance: 0.880
# Explained variance by component: [0.21741432 0.16197129 0.1423835  0.08913863 0.06927975 0.05882301
#  0.04331963 0.04032502 0.02769101 0.01976868]
# Total explained variance: 0.870
# Explained variance by component: [0.23610573 0.17679523 0.14430214 0.07371238 0.06863958 0.05907141
#  0.04162489 0.03757026 0.02753712 0.02022797]
# Total explained variance: 0.886
# Explained variance by component: [0.22879809 0.18009095 0.14675137 0.07631972 0.06974731 0.05909979
#  0.04241189 0.03688477 0.02811105 0.02004934]
# Total explained variance: 0.888
# Explained variance by component: [0.22939827 0.17685182 0.14616828 0.0755994  0.06909862 0.0602144
#  0.04172615 0.03813849 0.0269281  0.02069123]
# Total explained variance: 0.885
# Explained variance by component: [0.21668704 0.16576748 0.14363874 0.09132183 0.06895875 0.05916416
#  0.0431498  0.03923928 0.02753755 0.01934773]
# Total explained variance: 0.875
# Explained variance by component: [0.22773243 0.17845212 0.14626558 0.07392977 0.06929173 0.05916355
#  0.04221886 0.03781612 0.02758451 0.02094054]
# Total explained variance: 0.883
# Explained variance by component: [0.23228078 0.17892507 0.14481899 0.07195754 0.06817831 0.05892801
#  0.04274051 0.03637678 0.02778218 0.02088852]
# Total explained variance: 0.883
# Explained variance by component: [0.22917624 0.1824803  0.14704958 0.07181188 0.06930608 0.05937719
#  0.04311062 0.03648359 0.02815172 0.02011241]
# Total explained variance: 0.887
# Explained variance by component: [0.2314575  0.1713868  0.14498797 0.07828581 0.0689145  0.05996206
#  0.04244958 0.03842702 0.02633329 0.02071766]
# Total explained variance: 0.883
# Explained variance by component: [0.23387156 0.18060684 0.14471379 0.07360949 0.06898035 0.05956535
#  0.04316331 0.03610811 0.02801897 0.02001913]
# Total explained variance: 0.889
# Explained variance by component: [0.42758077 0.17180131 0.09830396 0.08072066 0.05770057 0.03629538
#  0.02925178 0.02007205 0.0145215  0.01343159]
# Total explained variance: 0.950
# Explained variance by component: [0.22883426 0.17226425 0.1454626  0.07732391 0.068106   0.06013737
#  0.04258832 0.03841384 0.02638736 0.02108661]
# Total explained variance: 0.881
# Explained variance by component: [0.2367781  0.17925097 0.156195   0.08790518 0.07710077 0.05135663
#  0.0407645  0.0287151  0.02192967 0.01950667]
# Total explained variance: 0.900
# Explained variance by component: [0.2364119  0.1789444  0.14624567 0.07196773 0.06866062 0.06084633
#  0.04214916 0.0356775  0.02717065 0.02010667]
# Total explained variance: 0.888
# Explained variance by component: [0.23496674 0.17949407 0.14492556 0.0750095  0.06913937 0.05926578
#  0.04281779 0.03644896 0.0284107  0.01978232]
# Total explained variance: 0.890
# Explained variance by component: [0.41681814 0.1780078  0.10212842 0.07817108 0.05926593 0.0343037
#  0.03003266 0.02134489 0.01528073 0.01386098]
# Total explained variance: 0.949
# Explained variance by component: [0.22061257 0.16455199 0.14364341 0.09386031 0.06949208 0.05834762
#  0.04347642 0.03885497 0.02811451 0.01958316]
# Total explained variance: 0.881
# Explained variance by component: [0.2345718  0.18016623 0.1457427  0.07292236 0.0691034  0.05940196
#  0.04255106 0.03615395 0.02837619 0.01995306]
# Total explained variance: 0.889
# Explained variance by component: [0.23926443 0.1663958  0.14701961 0.08829755 0.07413398 0.0581718
#  0.04368555 0.03054648 0.0277997  0.01736604]
# Total explained variance: 0.893
# Explained variance by component: [0.23899262 0.16443859 0.14808008 0.08827527 0.07461177 0.06070602
#  0.04418167 0.02960409 0.02689481 0.01651031]
# Total explained variance: 0.892
# Explained variance by component: [0.2681898  0.17439702 0.1374102  0.07836262 0.07511016 0.05643717
#  0.03982456 0.02989235 0.02505292 0.01825301]
# Total explained variance: 0.903
# Explained variance by component: [0.23027359 0.17743699 0.14586647 0.07350095 0.06884503 0.06021685
#  0.04298847 0.03705675 0.02676637 0.02068326]
# Total explained variance: 0.884
# Explained variance by component: [0.24236213 0.16153559 0.14695372 0.08743048 0.07406925 0.06099496
#  0.044711   0.03018511 0.02720863 0.01712467]
# Total explained variance: 0.893
# Explained variance by component: [0.23332311 0.17403057 0.14675228 0.07462958 0.06852524 0.05974627
#  0.04219197 0.03736892 0.0281061  0.02162571]
# Total explained variance: 0.886
# Explained variance by component: [0.2354364  0.17766178 0.14295274 0.07539379 0.0687205  0.05849209
#  0.04266395 0.03715703 0.02899443 0.019869  ]
# Total explained variance: 0.887
# Explained variance by component: [0.41094083 0.1603407  0.09926556 0.09232302 0.05805828 0.04318915
#  0.03060885 0.01950347 0.0162492  0.0123535 ]
# Total explained variance: 0.943
# Explained variance by component: [0.4252311  0.1724762  0.09901838 0.08164121 0.05813127 0.03552206
#  0.030163   0.02032955 0.01453293 0.01334042]
# Total explained variance: 0.950
# Explained variance by component: [0.27055043 0.16898681 0.14396572 0.08054479 0.07526975 0.05452999
#  0.04062485 0.03062869 0.02410819 0.01829924]
# Total explained variance: 0.908
# Explained variance by component: [0.22821032 0.17649119 0.14562097 0.0763414  0.06928474 0.06053809
#  0.04141755 0.03831047 0.02729809 0.02103359]
# Total explained variance: 0.885

# %%
cum_exp_var = np.cumsum(exp_var_all)
plt.figure(figsize=(7, 5))
plt.plot(range(1, len(exp_var_all) + 1), cum_exp_var, marker='o')
for i, var in enumerate(exp_var_all):
    plt.scatter(i + 1, cum_exp_var[i], s=var * 1000, alpha=0.3)
    # Add text annotation for individual component contribution
    plt.text(i + 1.1,
             cum_exp_var[i],
             f'{var:.2%}',
             fontsize=8,
             ha='left',
             va='center')
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance by PCA Components')
plt.grid(True)
plt.show()
# Out:
# /home/hgf_hmgu/hgf_gib4562/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/glfw/__init__.py:914: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)

# %%
# Define variable order and mapping to better names
variables = [
    'y_obs_cart_pos',
    'y_obs_cospole_ang',
    'y_obs_sinpole_ang',
    'y_obs_cart_vel',
    'y_obs_pole_vel',
    'reward',
    'action',
]

variable_name_mapping = {
    'y_obs_cart_pos': 'Cart Position',
    'y_obs_cospole_ang': 'Pole Angle (cos)',
    'y_obs_sinpole_ang': 'Pole Angle (sin)',
    'y_obs_cart_vel': 'Cart Velocity',
    'y_obs_pole_vel': 'Pole Velocity',
    'reward': 'Reward',
    'action': 'Action',
}

fig, ax = plt.subplots(figsize=(10, 8))

# Create the heatmap with better color normalization
im = ax.imshow(np.abs(corr_pca_all),
               aspect='auto',
               cmap='Reds',
               vmin=0,
               vmax=1,
               interpolation='none')

# Add colorbar with better formatting
cbar = plt.colorbar(im, ax=ax, label='|Correlation|', fraction=0.046, pad=0.04)
cbar.ax.tick_params(labelsize=11)
cbar.set_label('|Correlation|', fontsize=13, weight='bold')

# Set labels with better formatting
ax.set_xlabel('y vars (obs+rew+act)', fontsize=13, weight='bold')
ax.set_ylabel('PC Components', fontsize=13, weight='bold')
ax.set_title('PC components <-> y vars Correlation Matrix',
             fontsize=15,
             weight='bold',
             pad=15)

# Set x-axis tick labels using variable names
ax.set_xticks(np.arange(len(variables)))
ax.set_xticklabels([variable_name_mapping[v] for v in variables],
                   rotation=45,
                   ha='right')

# Improve tick labels
ax.tick_params(axis='both', which='major', labelsize=11)

# Add grid for better readability
ax.set_xticks(np.arange(corr_pca_all.shape[1]) - 0.5, minor=True)
ax.set_yticks(np.arange(corr_pca_all.shape[0]) - 0.5, minor=True)
ax.grid(which='minor', color='gray', linestyle='-', linewidth=0.5, alpha=0.2)

# Remove minor ticks but keep grid
ax.tick_params(which='minor', size=0)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Stability analysis

# %%
k = comps_pca_all.shape[0]
E = len(comps_pca_eps)
stability = np.zeros(
    (k, E))  # similarity of pooled comp i to best match in episode e

for i in range(k):
    w = comps_pca_all[i]  # (D,)
    for e in range(E):
        pc = comps_pca_eps[e][i]  # (k_e, D)
        # absolute dot products between w and all pcs in episode e
        dots = np.abs(pc @ w)  # (k_e,)
        best = dots.max()
        stability[i, e] = best

# summary stats per pooled component
mean_sim = stability.mean(axis=1)  # (k,)
std_sim = stability.std(axis=1)
median_sim = np.median(stability, axis=1)
frac_above = (stability >= 0.7).mean(
    axis=1)  # fraction of episodes where best match >= 0.7

# Example: print top stable components
for i in np.argsort(-mean_sim)[:10]:
    print(
        f"comp {i}: mean={mean_sim[i]:.3f}, std={std_sim[i]:.3f}, frac_above0.7={frac_above[i]:.2f}"
    )
# Out:
# comp 0: mean=0.850, std=0.257, frac_above0.7=0.91
# comp 1: mean=0.830, std=0.192, frac_above0.7=0.84
# comp 5: mean=0.818, std=0.201, frac_above0.7=0.78
# comp 4: mean=0.799, std=0.271, frac_above0.7=0.84
# comp 2: mean=0.773, std=0.176, frac_above0.7=0.78
# comp 9: mean=0.741, std=0.339, frac_above0.7=0.69
# comp 8: mean=0.695, std=0.350, frac_above0.7=0.69
# comp 3: mean=0.675, std=0.226, frac_above0.7=0.67
# comp 6: mean=0.252, std=0.303, frac_above0.7=0.22
# comp 7: mean=0.247, std=0.201, frac_above0.7=0.09

# %%
plt.figure(figsize=(12, 6))
plt.imshow(stability, aspect='auto', cmap='viridis')
plt.colorbar(label='Stability (max absolute dot product)')
plt.xlabel('Episode')
plt.ylabel('Pooled Component')
plt.title('Stability Matrix: Pooled Components vs Episodes')
plt.tight_layout()
plt.show()

# %%
idx = 0
w = comps_pca_all[idx]
plt.figure(figsize=(12, 4))
plt.stem(abs(w))
plt.xlabel('Latent dimension')
plt.ylabel('Weight')
plt.title('PCA Component Weights')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
np.savez('selected_dirs_pca_mt30-317.npz', comps_pca_all=comps_pca_all)

# %% [markdown]
# ## sparsitfy directions

# %%
fig, axs = plt.subplots(1, 3, figsize=(18, 4))

eps_idx = 0
axs[0].plot(observations[eps_idx])
axs[0].set_title('Observations[0]')
axs[0].set_xlabel('Time')
axs[0].set_ylabel('Observation value')

axs[1].plot(rewards[eps_idx])
axs[1].set_title('Rewards[0]')
axs[1].set_xlabel('Time')
axs[1].set_ylabel('Reward')

axs[2].plot(actions[eps_idx])
axs[2].set_title('Actions[0]')
axs[2].set_xlabel('Time')
axs[2].set_ylabel('Action')

plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 3, figsize=(15, 4))

for i in range(3):
    axs[i].plot(F_all[:, i])
    axs[i].set_title(f'PCA Component {i+1}')
    axs[i].set_xlabel('Time')
    axs[i].set_ylabel('Value')

plt.tight_layout()
plt.show()

# %%
def denoise_pca_direction_np(v, eps_frac=1e-3):
    """
    v: original PCA component (1D numpy array)
    eps_frac: threshold fraction of max(abs(v))
    returns: v_hat (unit vector), cosine_sim, n_nonzero
    """
    v = v.astype(float)
    maxabs = np.max(np.abs(v))
    thr = eps_frac * maxabs
    v_thr = v.copy()
    v_thr[np.abs(v_thr) < thr] = 0.0
    norm = np.linalg.norm(v_thr)
    if norm == 0:
        raise ValueError("threshold too large; all entries zeroed")
    v_hat = v_thr / norm
    cosine = float(np.dot(v_hat, v) / (np.linalg.norm(v) + 1e-12))
    return v_hat, cosine, int((np.abs(v_hat) > 0).sum())

# %%
eps_fracs = [
    0, 0.01, 0.05, 0.1, 0.15, 0.2, 0.25, 0.3, 0.35, 0.4, 0.45, 0.5, 0.55, 0.6,
    0.65, 0.7, 0.75, 0.8, 0.85, 0.9, 0.95, 1.0
]
results = {}
for idx, comp in enumerate(comps_pca_all):
    results[idx] = {}
    for eps_frac in eps_fracs:
        vhat, cosine, n_nonzero = denoise_pca_direction_np(comp,
                                                           eps_frac=eps_frac)
        results[idx][eps_frac] = {
            "comp_sparse": vhat,
            "cosine": cosine,
            "n_nonzero": n_nonzero,
        }
        print(
            f"component: {idx}, eps_frac: {eps_frac}, cosine: {cosine}, n_nonzero: {n_nonzero}"
        )
# Out:
# component: 0, eps_frac: 0, cosine: 0.9999999999989999, n_nonzero: 512
# component: 0, eps_frac: 0.01, cosine: 0.9999825719588856, n_nonzero: 490
# component: 0, eps_frac: 0.05, cosine: 0.9979355306336901, n_nonzero: 368
# component: 0, eps_frac: 0.1, cosine: 0.9854555746493752, n_nonzero: 244
# component: 0, eps_frac: 0.15, cosine: 0.9592987839168002, n_nonzero: 155
# component: 0, eps_frac: 0.2, cosine: 0.931089778896585, n_nonzero: 109
# component: 0, eps_frac: 0.25, cosine: 0.9067390290004379, n_nonzero: 86
# component: 0, eps_frac: 0.3, cosine: 0.8781776933752498, n_nonzero: 68
# component: 0, eps_frac: 0.35, cosine: 0.844934327033353, n_nonzero: 53
# component: 0, eps_frac: 0.4, cosine: 0.8102438408613983, n_nonzero: 42
# component: 0, eps_frac: 0.45, cosine: 0.7808061909348849, n_nonzero: 35
# component: 0, eps_frac: 0.5, cosine: 0.7471136884868426, n_nonzero: 29
# component: 0, eps_frac: 0.55, cosine: 0.7276864260481666, n_nonzero: 26
# component: 0, eps_frac: 0.6, cosine: 0.6824384811877512, n_nonzero: 21
# component: 0, eps_frac: 0.65, cosine: 0.6483298802905898, n_nonzero: 18
# component: 0, eps_frac: 0.7, cosine: 0.5473435764590794, n_nonzero: 11
# component: 0, eps_frac: 0.75, cosine: 0.5106245208355858, n_nonzero: 9
# component: 0, eps_frac: 0.8, cosine: 0.48781172710278814, n_nonzero: 8
# component: 0, eps_frac: 0.85, cosine: 0.4044815409835245, n_nonzero: 5
# component: 0, eps_frac: 0.9, cosine: 0.3236522832269426, n_nonzero: 3
# component: 0, eps_frac: 0.95, cosine: 0.19413634415536793, n_nonzero: 1
# component: 0, eps_frac: 1.0, cosine: 0.19413634415536793, n_nonzero: 1
# component: 1, eps_frac: 0, cosine: 0.9999999999990001, n_nonzero: 512
# component: 1, eps_frac: 0.01, cosine: 0.999972645512295, n_nonzero: 478
# component: 1, eps_frac: 0.05, cosine: 0.9978775791715107, n_nonzero: 362
# component: 1, eps_frac: 0.1, cosine: 0.9848411481562879, n_nonzero: 256
# component: 1, eps_frac: 0.15, cosine: 0.9642926563433746, n_nonzero: 193
# component: 1, eps_frac: 0.2, cosine: 0.9298631657663616, n_nonzero: 140
# component: 1, eps_frac: 0.25, cosine: 0.8853648815527483, n_nonzero: 100
# component: 1, eps_frac: 0.3, cosine: 0.8357006195395881, n_nonzero: 72
# component: 1, eps_frac: 0.35, cosine: 0.7893162566243227, n_nonzero: 54
# component: 1, eps_frac: 0.4, cosine: 0.7435479908448578, n_nonzero: 41
# component: 1, eps_frac: 0.45, cosine: 0.7037598954205387, n_nonzero: 33
# component: 1, eps_frac: 0.5, cosine: 0.6586903853709744, n_nonzero: 26
# component: 1, eps_frac: 0.55, cosine: 0.5701103248486504, n_nonzero: 16
# component: 1, eps_frac: 0.6, cosine: 0.506176212552367, n_nonzero: 11
# component: 1, eps_frac: 0.65, cosine: 0.4561405206003822, n_nonzero: 8
# component: 1, eps_frac: 0.7, cosine: 0.4365484783845017, n_nonzero: 7
# component: 1, eps_frac: 0.75, cosine: 0.3871077703737981, n_nonzero: 5
# component: 1, eps_frac: 0.8, cosine: 0.3188113074554892, n_nonzero: 3
# component: 1, eps_frac: 0.85, cosine: 0.2749508359837846, n_nonzero: 2
# component: 1, eps_frac: 0.9, cosine: 0.2749508359837846, n_nonzero: 2
# component: 1, eps_frac: 0.95, cosine: 0.2011692977916594, n_nonzero: 1
# component: 1, eps_frac: 1.0, cosine: 0.2011692977916594, n_nonzero: 1
# component: 2, eps_frac: 0, cosine: 0.9999999999989997, n_nonzero: 512
# component: 2, eps_frac: 0.01, cosine: 0.9999847423950298, n_nonzero: 483
# component: 2, eps_frac: 0.05, cosine: 0.998736172093382, n_nonzero: 381
# component: 2, eps_frac: 0.1, cosine: 0.9930987304683542, n_nonzero: 297
# component: 2, eps_frac: 0.15, cosine: 0.984138078450053, n_nonzero: 252
# component: 2, eps_frac: 0.2, cosine: 0.9597451493979964, n_nonzero: 189
# component: 2, eps_frac: 0.25, cosine: 0.9304262798721775, n_nonzero: 144
# component: 2, eps_frac: 0.3, cosine: 0.9052765306978053, n_nonzero: 119
# component: 2, eps_frac: 0.35, cosine: 0.8710446784975237, n_nonzero: 95
# component: 2, eps_frac: 0.4, cosine: 0.8471424983362289, n_nonzero: 83
# component: 2, eps_frac: 0.45, cosine: 0.8102185352008302, n_nonzero: 69
# component: 2, eps_frac: 0.5, cosine: 0.7218514222825065, n_nonzero: 45
# component: 2, eps_frac: 0.55, cosine: 0.6726388451292918, n_nonzero: 35
# component: 2, eps_frac: 0.6, cosine: 0.6360014462432018, n_nonzero: 29
# component: 2, eps_frac: 0.65, cosine: 0.58896685069188, n_nonzero: 23
# component: 2, eps_frac: 0.7, cosine: 0.5174555223298596, n_nonzero: 16
# component: 2, eps_frac: 0.75, cosine: 0.4783589707860751, n_nonzero: 13
# component: 2, eps_frac: 0.8, cosine: 0.3942938075858234, n_nonzero: 8
# component: 2, eps_frac: 0.85, cosine: 0.2950250513585432, n_nonzero: 4
# component: 2, eps_frac: 0.9, cosine: 0.26109833824226597, n_nonzero: 3
# component: 2, eps_frac: 0.95, cosine: 0.21765951963452143, n_nonzero: 2
# component: 2, eps_frac: 1.0, cosine: 0.1570096799239149, n_nonzero: 1
# component: 3, eps_frac: 0, cosine: 0.9999999999989997, n_nonzero: 512
# component: 3, eps_frac: 0.01, cosine: 0.9999916847461963, n_nonzero: 489
# component: 3, eps_frac: 0.05, cosine: 0.9985742046046922, n_nonzero: 378
# component: 3, eps_frac: 0.1, cosine: 0.9918519993362239, n_nonzero: 291
# component: 3, eps_frac: 0.15, cosine: 0.9780375303613935, n_nonzero: 223
# component: 3, eps_frac: 0.2, cosine: 0.9564976238188733, n_nonzero: 171
# component: 3, eps_frac: 0.25, cosine: 0.9378361093057691, n_nonzero: 145
# component: 3, eps_frac: 0.3, cosine: 0.8981095394077014, n_nonzero: 110
# component: 3, eps_frac: 0.35, cosine: 0.8645867962123905, n_nonzero: 89
# component: 3, eps_frac: 0.4, cosine: 0.8231901150068796, n_nonzero: 70
# component: 3, eps_frac: 0.45, cosine: 0.7719973363644806, n_nonzero: 53
# component: 3, eps_frac: 0.5, cosine: 0.7390653816225514, n_nonzero: 45
# component: 3, eps_frac: 0.55, cosine: 0.6866309751773273, n_nonzero: 35
# component: 3, eps_frac: 0.6, cosine: 0.6388118926258154, n_nonzero: 28
# component: 3, eps_frac: 0.65, cosine: 0.55779734636309, n_nonzero: 19
# component: 3, eps_frac: 0.7, cosine: 0.5006839550843571, n_nonzero: 14
# component: 3, eps_frac: 0.75, cosine: 0.4225116262883625, n_nonzero: 9
# component: 3, eps_frac: 0.8, cosine: 0.36114096883863694, n_nonzero: 6
# component: 3, eps_frac: 0.85, cosine: 0.3057547882007293, n_nonzero: 4
# component: 3, eps_frac: 0.9, cosine: 0.27027580364651677, n_nonzero: 3
# component: 3, eps_frac: 0.95, cosine: 0.1639040117913237, n_nonzero: 1
# component: 3, eps_frac: 1.0, cosine: 0.1639040117913237, n_nonzero: 1
# component: 4, eps_frac: 0, cosine: 0.9999999999989999, n_nonzero: 512
# component: 4, eps_frac: 0.01, cosine: 0.9999689647345407, n_nonzero: 462
# component: 4, eps_frac: 0.05, cosine: 0.9975251331076241, n_nonzero: 338
# component: 4, eps_frac: 0.1, cosine: 0.9888465191789922, n_nonzero: 257
# component: 4, eps_frac: 0.15, cosine: 0.9713286476751032, n_nonzero: 198
# component: 4, eps_frac: 0.2, cosine: 0.9366229741268535, n_nonzero: 142
# component: 4, eps_frac: 0.25, cosine: 0.9025651293629433, n_nonzero: 109
# component: 4, eps_frac: 0.3, cosine: 0.8608093090508948, n_nonzero: 83
# component: 4, eps_frac: 0.35, cosine: 0.802088310407178, n_nonzero: 59
# component: 4, eps_frac: 0.4, cosine: 0.746586574416247, n_nonzero: 43
# component: 4, eps_frac: 0.45, cosine: 0.7074995647344298, n_nonzero: 35
# component: 4, eps_frac: 0.5, cosine: 0.6240059412340435, n_nonzero: 22
# component: 4, eps_frac: 0.55, cosine: 0.581325161647315, n_nonzero: 17
# component: 4, eps_frac: 0.6, cosine: 0.5699854962121202, n_nonzero: 16
# component: 4, eps_frac: 0.65, cosine: 0.5034756586684309, n_nonzero: 11
# component: 4, eps_frac: 0.7, cosine: 0.4078798377088891, n_nonzero: 6
# component: 4, eps_frac: 0.75, cosine: 0.3816946031555288, n_nonzero: 5
# component: 4, eps_frac: 0.8, cosine: 0.34897146245243055, n_nonzero: 4
# component: 4, eps_frac: 0.85, cosine: 0.2599584132404342, n_nonzero: 2
# component: 4, eps_frac: 0.9, cosine: 0.19582193237976053, n_nonzero: 1
# component: 4, eps_frac: 0.95, cosine: 0.19582193237976053, n_nonzero: 1
# component: 4, eps_frac: 1.0, cosine: 0.19582193237976053, n_nonzero: 1
# component: 5, eps_frac: 0, cosine: 0.999999999999, n_nonzero: 512
# component: 5, eps_frac: 0.01, cosine: 0.9999572687948092, n_nonzero: 470
# component: 5, eps_frac: 0.05, cosine: 0.9968555413460891, n_nonzero: 331
# component: 5, eps_frac: 0.1, cosine: 0.9821803598405909, n_nonzero: 229
# component: 5, eps_frac: 0.15, cosine: 0.9571803752018936, n_nonzero: 166
# component: 5, eps_frac: 0.2, cosine: 0.9101121746417438, n_nonzero: 108
# component: 5, eps_frac: 0.25, cosine: 0.8679393643614659, n_nonzero: 79
# component: 5, eps_frac: 0.3, cosine: 0.8355816199651015, n_nonzero: 65
# component: 5, eps_frac: 0.35, cosine: 0.7739807687408898, n_nonzero: 46
# component: 5, eps_frac: 0.4, cosine: 0.7106845373393321, n_nonzero: 32
# component: 5, eps_frac: 0.45, cosine: 0.6510241651516906, n_nonzero: 23
# component: 5, eps_frac: 0.5, cosine: 0.5786821464598452, n_nonzero: 15
# component: 5, eps_frac: 0.55, cosine: 0.5018881450154508, n_nonzero: 9
# component: 5, eps_frac: 0.6, cosine: 0.5018881450154508, n_nonzero: 9
# component: 5, eps_frac: 0.65, cosine: 0.48237255837446646, n_nonzero: 8
# component: 5, eps_frac: 0.7, cosine: 0.3772012240911178, n_nonzero: 4
# component: 5, eps_frac: 0.75, cosine: 0.3025573289393757, n_nonzero: 2
# component: 5, eps_frac: 0.8, cosine: 0.3025573289393757, n_nonzero: 2
# component: 5, eps_frac: 0.85, cosine: 0.3025573289393757, n_nonzero: 2
# component: 5, eps_frac: 0.9, cosine: 0.3025573289393757, n_nonzero: 2
# component: 5, eps_frac: 0.95, cosine: 0.22332658627943133, n_nonzero: 1
# component: 5, eps_frac: 1.0, cosine: 0.22332658627943133, n_nonzero: 1
# component: 6, eps_frac: 0, cosine: 0.999999999999, n_nonzero: 512
# component: 6, eps_frac: 0.01, cosine: 0.9999864171989543, n_nonzero: 481
# component: 6, eps_frac: 0.05, cosine: 0.998300923896145, n_nonzero: 379
# component: 6, eps_frac: 0.1, cosine: 0.989334735861322, n_nonzero: 290
# component: 6, eps_frac: 0.15, cosine: 0.9694329028941412, n_nonzero: 218
# component: 6, eps_frac: 0.2, cosine: 0.9405288114655022, n_nonzero: 170
# component: 6, eps_frac: 0.25, cosine: 0.8924400411696545, n_nonzero: 121
# component: 6, eps_frac: 0.3, cosine: 0.8571981572327305, n_nonzero: 98
# component: 6, eps_frac: 0.35, cosine: 0.7942689887159892, n_nonzero: 70
# component: 6, eps_frac: 0.4, cosine: 0.7404696755403369, n_nonzero: 53
# component: 6, eps_frac: 0.45, cosine: 0.69221679586877, n_nonzero: 42
# component: 6, eps_frac: 0.5, cosine: 0.5897176509551153, n_nonzero: 25
# component: 6, eps_frac: 0.55, cosine: 0.5045790441118226, n_nonzero: 15
# component: 6, eps_frac: 0.6, cosine: 0.44446696324874274, n_nonzero: 10
# component: 6, eps_frac: 0.65, cosine: 0.43006284232960196, n_nonzero: 9
# component: 6, eps_frac: 0.7, cosine: 0.39065403322772385, n_nonzero: 7
# component: 6, eps_frac: 0.75, cosine: 0.31312614052051, n_nonzero: 4
# component: 6, eps_frac: 0.8, cosine: 0.23935302390610946, n_nonzero: 2
# component: 6, eps_frac: 0.85, cosine: 0.18660074372056729, n_nonzero: 1
# component: 6, eps_frac: 0.9, cosine: 0.18660074372056729, n_nonzero: 1
# component: 6, eps_frac: 0.95, cosine: 0.18660074372056729, n_nonzero: 1
# component: 6, eps_frac: 1.0, cosine: 0.18660074372056729, n_nonzero: 1
# component: 7, eps_frac: 0, cosine: 0.9999999999990001, n_nonzero: 512
# component: 7, eps_frac: 0.01, cosine: 0.9999836632747267, n_nonzero: 481
# component: 7, eps_frac: 0.05, cosine: 0.9986283552433538, n_nonzero: 384
# component: 7, eps_frac: 0.1, cosine: 0.9914808228200245, n_nonzero: 305
# component: 7, eps_frac: 0.15, cosine: 0.9769489369533235, n_nonzero: 247
# component: 7, eps_frac: 0.2, cosine: 0.9501176913484001, n_nonzero: 193
# component: 7, eps_frac: 0.25, cosine: 0.9030793635035315, n_nonzero: 139
# component: 7, eps_frac: 0.3, cosine: 0.8512249480904427, n_nonzero: 100
# component: 7, eps_frac: 0.35, cosine: 0.795504770195331, n_nonzero: 73
# component: 7, eps_frac: 0.4, cosine: 0.7454470660360376, n_nonzero: 56
# component: 7, eps_frac: 0.45, cosine: 0.6924684000430019, n_nonzero: 43
# component: 7, eps_frac: 0.5, cosine: 0.6303423600451895, n_nonzero: 31
# component: 7, eps_frac: 0.55, cosine: 0.5517780499115085, n_nonzero: 20
# component: 7, eps_frac: 0.6, cosine: 0.4906345882165731, n_nonzero: 14
# component: 7, eps_frac: 0.65, cosine: 0.4243210402378801, n_nonzero: 9
# component: 7, eps_frac: 0.7, cosine: 0.39071217016437115, n_nonzero: 7
# component: 7, eps_frac: 0.75, cosine: 0.34575527375300386, n_nonzero: 5
# component: 7, eps_frac: 0.8, cosine: 0.34575527375300386, n_nonzero: 5
# component: 7, eps_frac: 0.85, cosine: 0.1776324853870864, n_nonzero: 1
# component: 7, eps_frac: 0.9, cosine: 0.1776324853870864, n_nonzero: 1
# component: 7, eps_frac: 0.95, cosine: 0.1776324853870864, n_nonzero: 1
# component: 7, eps_frac: 1.0, cosine: 0.1776324853870864, n_nonzero: 1
# component: 8, eps_frac: 0, cosine: 0.9999999999989999, n_nonzero: 512
# component: 8, eps_frac: 0.01, cosine: 0.9999913787480803, n_nonzero: 487
# component: 8, eps_frac: 0.05, cosine: 0.998912233039075, n_nonzero: 392
# component: 8, eps_frac: 0.1, cosine: 0.9934164781133941, n_nonzero: 308
# component: 8, eps_frac: 0.15, cosine: 0.9816671898982882, n_nonzero: 249
# component: 8, eps_frac: 0.2, cosine: 0.9652419675177792, n_nonzero: 206
# component: 8, eps_frac: 0.25, cosine: 0.9366125074538323, n_nonzero: 161
# component: 8, eps_frac: 0.3, cosine: 0.9047609282537774, n_nonzero: 129
# component: 8, eps_frac: 0.35, cosine: 0.8609576665641421, n_nonzero: 99
# component: 8, eps_frac: 0.4, cosine: 0.8156598639692607, n_nonzero: 77
# component: 8, eps_frac: 0.45, cosine: 0.7794598681542839, n_nonzero: 64
# component: 8, eps_frac: 0.5, cosine: 0.7299894691879338, n_nonzero: 50
# component: 8, eps_frac: 0.55, cosine: 0.6934371923978919, n_nonzero: 42
# component: 8, eps_frac: 0.6, cosine: 0.6531563014016706, n_nonzero: 35
# component: 8, eps_frac: 0.65, cosine: 0.543245579984166, n_nonzero: 21
# component: 8, eps_frac: 0.7, cosine: 0.4999412090012981, n_nonzero: 17
# component: 8, eps_frac: 0.75, cosine: 0.3708141760090139, n_nonzero: 8
# component: 8, eps_frac: 0.8, cosine: 0.3290709347621278, n_nonzero: 6
# component: 8, eps_frac: 0.85, cosine: 0.20876356300611223, n_nonzero: 2
# component: 8, eps_frac: 0.9, cosine: 0.15538523063282952, n_nonzero: 1
# component: 8, eps_frac: 0.95, cosine: 0.15538523063282952, n_nonzero: 1
# component: 8, eps_frac: 1.0, cosine: 0.15538523063282952, n_nonzero: 1
# component: 9, eps_frac: 0, cosine: 0.9999999999990002, n_nonzero: 512
# component: 9, eps_frac: 0.01, cosine: 0.9999908301910562, n_nonzero: 488
# component: 9, eps_frac: 0.05, cosine: 0.9991181976105235, n_nonzero: 412
# component: 9, eps_frac: 0.1, cosine: 0.9937113859926506, n_nonzero: 334
# component: 9, eps_frac: 0.15, cosine: 0.9821509830938883, n_nonzero: 271
# component: 9, eps_frac: 0.2, cosine: 0.9641625788035969, n_nonzero: 224
# component: 9, eps_frac: 0.25, cosine: 0.9335811441049224, n_nonzero: 178
# component: 9, eps_frac: 0.3, cosine: 0.8909443718779194, n_nonzero: 134
# component: 9, eps_frac: 0.35, cosine: 0.8511586895825632, n_nonzero: 106
# component: 9, eps_frac: 0.4, cosine: 0.8005822575007221, n_nonzero: 81
# component: 9, eps_frac: 0.45, cosine: 0.7503119045766625, n_nonzero: 62
# component: 9, eps_frac: 0.5, cosine: 0.6777754031547545, n_nonzero: 43
# component: 9, eps_frac: 0.55, cosine: 0.6288761585153723, n_nonzero: 33
# component: 9, eps_frac: 0.6, cosine: 0.5637312857836343, n_nonzero: 23
# component: 9, eps_frac: 0.65, cosine: 0.5399065289020185, n_nonzero: 20
# component: 9, eps_frac: 0.7, cosine: 0.49764903077246786, n_nonzero: 16
# component: 9, eps_frac: 0.75, cosine: 0.40090831312114544, n_nonzero: 9
# component: 9, eps_frac: 0.8, cosine: 0.36455894286416657, n_nonzero: 7
# component: 9, eps_frac: 0.85, cosine: 0.3425090124043252, n_nonzero: 6
# component: 9, eps_frac: 0.9, cosine: 0.25196062979042205, n_nonzero: 3
# component: 9, eps_frac: 0.95, cosine: 0.15356181603613095, n_nonzero: 1
# component: 9, eps_frac: 1.0, cosine: 0.15356181603613095, n_nonzero: 1

# %%
import matplotlib as mpl

# Set up a red colormap from bright to dark (brightest red to darkest red)
num_components = len(results.keys())
cmap = mpl.cm.get_cmap('Reds', num_components)
# To make the brightest red correspond to idx=0, reverse the colors
colors = [
    cmap(1.0 - (i / max(1, num_components - 1))) for i in range(num_components)
]

fig, axs = plt.subplots(1, 2, figsize=(14, 5))

# Plot cosine similarity and n_nonzero with red color mapping
for i, idx in enumerate(results.keys()):
    epsilons = []
    cosines = []
    n_nonzero = []
    for eps_frac in eps_fracs:
        epsilons.append(eps_frac)
        cosines.append(results[idx][eps_frac]["cosine"])
        n_nonzero.append(results[idx][eps_frac]["n_nonzero"])
    axs[0].plot(epsilons,
                cosines,
                marker='o',
                label=f'Component {idx}',
                color=colors[i])
    axs[1].plot(epsilons,
                n_nonzero,
                marker='o',
                label=f'Component {idx}',
                color=colors[i])

axs[0].set_xlabel('eps_frac')
axs[0].set_ylabel('Cosine similarity')
axs[0].set_title('Cosine similarity vs eps_frac')

axs[1].set_xlabel('eps_frac')
axs[1].set_ylabel('n_nonzero')
axs[1].set_title('n_nonzero vs eps_frac')

axs[0].legend()
axs[0].grid(True)
axs[1].legend()
axs[1].grid(True)

plt.tight_layout()
plt.show()
# Out:
# /scratch/slurm_tmpdir/job_1585480/ipykernel_1987438/4087605059.py:5: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = mpl.cm.get_cmap('Reds', num_components)

# %%
import pickle
with open("selected_dirs_pca_sparse_all.pkl", "wb") as f:
    pickle.dump(results, f)

# %%
pc_components = (np.dot(comps_pca_all, latents_arr.T))
plt.figure(figsize=(14, 5))
plt.plot(pc_components[1])
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np

rr = results[0]

eps_fracs = sorted(rr.keys())
num_eps = len(eps_fracs) - 1

# Reds colormap from light to dark (low index = light, high = dark)
cmap = mpl.cm.get_cmap('Reds', num_eps)
colors = [cmap(i) for i in range(num_eps)]

plt.figure(figsize=(22, 12))  # wider figure
for idx, eps_frac in enumerate(eps_fracs[1:15]):
    plt.plot(latents_arr @ rr[eps_frac]["comp_sparse"].T,
             color=colors[idx],
             alpha=1.0,
             linewidth=3,
             label=f"eps_frac={eps_frac}")

plt.plot(latents_arr @ rr[0]["comp_sparse"].T,
         color='black',
         alpha=0.8,
         linewidth=3,
         label=f"eps_frac=0")

plt.legend()
plt.show()
# Out:
# /scratch/slurm_tmpdir/job_1585480/ipykernel_1987438/1264354044.py:11: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = mpl.cm.get_cmap('Reds', num_eps)

# %% [markdown]
# ## project latents into this one direction

# %%
cum_exp_var = np.cumsum(exp_var_all)
plt.figure(figsize=(5, 5))
plt.plot(cum_exp_var)
plt.xlabel('Number of Components')
plt.ylabel('Cumulative Explained Variance')
plt.title('Cumulative Explained Variance by PCA Components')
plt.grid(True)
plt.show()

# %%
import torch


def reconstruct_latents(latents,
                        components,
                        add_simnorm=True,
                        renormalize=False,
                        simnorm_dim=8):
    """Keep only first k PCA components, zero out all others"""
    # latents shape: (batch, latent_dim)
    # components shape: (k, latent_dim)

    # Project onto first k components and reconstruct
    coeffs = latents @ components.T  # (batch, k)
    latents_reconstructed = coeffs @ components  # (batch, latent_dim)

    if add_simnorm:
        # Re-apply SimNorm to maintain the model's expected distribution
        # SimNorm groups dimensions and applies softmax within each group
        shp = latents_reconstructed.shape
        latents_reconstructed = latents_reconstructed.view(
            *shp[:-1], -1, simnorm_dim)
        latents_reconstructed = torch.nn.functional.softmax(
            latents_reconstructed, dim=-1)
        latents_reconstructed = latents_reconstructed.view(*shp)

    if renormalize:
        # Simple min-max normalization to [0, 1] per sample
        min_vals = latents_reconstructed.min(dim=-1, keepdim=True)[0]
        max_vals = latents_reconstructed.max(dim=-1, keepdim=True)[0]
        latents_reconstructed = (latents_reconstructed -
                                 min_vals) / (max_vals - min_vals + 1e-8)
    return latents_reconstructed

# %%
reconstructed_latents = reconstruct_latents(torch.from_numpy(latents_arr),
                                            add_simnorm=False,
                                            renormalize=True,
                                            components=comps_pca_all[:1])

# %%
plt.plot(reconstructed_latents[:200])
plt.show()

# %%
corr_pca_all, comps_pca_all, exp_var_all, F_all = analyze_latent_to_observation_mapping(
    Xs=latents_arr,
    Ys=all_arrs,
    method="pca",
    n_components=100,
)

reconstructed_latents = reconstruct_latents(torch.from_numpy(latents_arr),
                                            add_simnorm=True,
                                            renormalize=False,
                                            components=comps_pca_all[:])
reconstructed_latents = reconstructed_latents.numpy()
# Out:
# Explained variance by component: [4.51449364e-01 1.00987010e-01 7.56025910e-02 6.47898093e-02
#  5.13321459e-02 4.48070876e-02 3.50235030e-02 2.85565630e-02
#  2.36014109e-02 1.80432592e-02 1.22563764e-02 1.00603430e-02
#  8.78421497e-03 7.31927948e-03 6.53641718e-03 5.90189453e-03
#  5.16313734e-03 4.42477781e-03 3.79582145e-03 3.57178762e-03
#  3.28681758e-03 2.96219694e-03 2.92549445e-03 2.20293039e-03
#  2.09251395e-03 1.89772423e-03 1.84961385e-03 1.65873207e-03
#  1.50558806e-03 1.22605520e-03 1.10246462e-03 1.02032628e-03
#  9.32811992e-04 8.79718922e-04 8.39869375e-04 6.48166460e-04
#  6.26832014e-04 6.02824730e-04 5.77451603e-04 5.29142271e-04
#  4.90579114e-04 4.78354399e-04 4.26624407e-04 3.83182429e-04
#  3.49373615e-04 3.42973595e-04 3.34135751e-04 3.11915559e-04
#  2.85137969e-04 2.77917716e-04 2.38751847e-04 2.26204225e-04
#  2.14766347e-04 1.96743218e-04 1.87598882e-04 1.80072093e-04
#  1.68993472e-04 1.68187107e-04 1.61479926e-04 1.45099242e-04
#  1.42703604e-04 1.31674024e-04 1.21598205e-04 1.12016693e-04
#  1.08841370e-04 1.06917614e-04 1.03630948e-04 9.87748208e-05
#  9.27871079e-05 8.78995997e-05 8.31337820e-05 8.05856835e-05
#  7.35881258e-05 7.19341479e-05 6.81408274e-05 6.13396478e-05
#  6.11145369e-05 5.84837544e-05 5.52491620e-05 5.26400727e-05
#  5.11814542e-05 4.90331804e-05 4.71518870e-05 4.60778210e-05
#  4.27227969e-05 4.08205306e-05 4.01185061e-05 3.73847251e-05
#  3.63381223e-05 3.52665920e-05 3.45199987e-05 3.20115578e-05
#  3.07382725e-05 3.01209584e-05 2.71776771e-05 2.64562696e-05
#  2.61144796e-05 2.48885462e-05 2.40071877e-05 2.32111324e-05]
# Total explained variance: 0.999

# %%
print("Reconstruction error:", np.mean(
    (latents_arr - reconstructed_latents)**2))
# Out:
# Reconstruction error: 0.026538609

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 6))

# Plot original latents
n_points_to_plot = 20
for i in range(10):
    ax1.plot(latents_arr[:n_points_to_plot, i], label=f'Latent {i}', alpha=0.7)
ax1.set_title('Original Latents')
ax1.legend()
ax1.grid(True, alpha=0.3)

# Plot reconstructed latents
for i in range(10):
    ax2.plot(reconstructed_latents[:n_points_to_plot, i],
             label=f'Latent {i}',
             alpha=0.7)
ax2.set_title('Reconstructed Latents')
ax2.legend()
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
import numpy as np
from sklearn.decomposition import PCA


def pca_reconstruct(X, n_components):
    """
    Perform PCA on X with n_components and reconstruct the data.
    
    Parameters
    ----------
    X : np.ndarray
        Input data of shape (N, d).
    n_components : int
        Number of principal components to retain.
    
    Returns
    -------
    X_reconstructed : np.ndarray
        Reconstructed version of X, same shape as X.
    pca : PCA object
        The fitted PCA model.
    """
    # Fit PCA
    pca = PCA(n_components=n_components)
    Z = pca.fit_transform(X)  # (N, n_components)

    # Reconstruct data
    X_reconstructed = pca.inverse_transform(Z)  # (N, d)

    return X_reconstructed, pca

# %%
X = np.random.randn(1000, 200)
X_rec, pca = pca_reconstruct(X, n_components=200)

print("Reconstruction error:", np.mean((X - X_rec)**2))
# Out:
# Reconstruction error: 8.029760337364685e-30
