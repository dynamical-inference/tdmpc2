# %%
import numpy as np
import matplotlib.pyplot as plt
import sys

# Add parent directory to path for imports
sys.path.insert(0, "/home/hgf_hmgu/hgf_gib4562/tdmpc2/")

#from analysis.load_run_data import load_run_data
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from rastermap import Rastermap
import numpy as np
from itertools import combinations
from sklearn.linear_model import RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import r2_score
import pickle
from tqdm import tqdm

from sklearn.linear_model import LinearRegression, Lasso, MultiTaskLasso
from sklearn.metrics import r2_score
import pandas as pd

from analysis.utils import fit_rastermap, plot_rastermap_with_rewards_actions

# %%
import json
from pathlib import Path
import pandas as pd


def flatten_dict(d, parent_key='', sep='_'):
    """
    Flatten a nested dictionary.
    
    Args:
        d: Dictionary to flatten
        parent_key: String to prepend to keys
        sep: Separator between nested keys
    
    Returns:
        Flattened dictionary
    """
    items = []
    for k, v in d.items():
        new_key = f"{parent_key}{sep}{k}" if parent_key else k
        if isinstance(v, dict):
            items.extend(flatten_dict(v, new_key, sep=sep).items())
        else:
            items.append((new_key, v))
    return dict(items)


# Loop over all directories in the sweep logs
sweep_base_dir = Path(
    "/home/hgf_hmgu/hgf_gib4562/tdmpc2/logs/latent_interventions_sweep")

all_metadata = []
for sweep_dir in sweep_base_dir.iterdir():
    if sweep_dir.is_dir():
        metadata_path = sweep_dir / "activations" / "episode_0000_metadata.json"
        if metadata_path.exists():
            with open(metadata_path, 'r') as f:
                metadata = json.load(f)
                # Flatten the nested metadata dictionary
                flattened_metadata = flatten_dict(metadata)
                # Add the directory path
                flattened_metadata['directory'] = str(sweep_dir)
                all_metadata.append(flattened_metadata)

print(f"Found {len(all_metadata)} configurations")

# Create DataFrame from flattened metadata
df_metadata = pd.DataFrame(all_metadata)
# Out:
# Found 1260 configurations

# %%
df_metadata.head()
# Out:
#                                   config_id config_type config_location  \
# 0         ablationdims200-hinge1_2.32-seed4    ablation  encoder_output
# 1   noisedims10-scale0.1-hinge1_-2.73-seed1       noise  encoder_output
# 2    noisedims100-scale0.1-hinge1_1.5-seed3       noise  encoder_output
# 3  noisedims200-scale0.1-hinge1_-2.32-seed2       noise  encoder_output
# 4  noisedims300-scale1.0-hinge1_-1.91-seed4       noise  encoder_output
#
#    config_num_dims  config_hinge_1_value  config_seed  \
# 0              200                  2.32            4
# 1               10                 -2.73            1
# 2              100                  1.50            3
# 3              200                 -2.32            2
# 4              300                 -1.91            4
#
#                                        dims_affected  \
# 0  [380, 89, 192, 102, 210, 394, 254, 403, 8, 443...
# 1  [47, 345, 284, 221, 503, 168, 223, 189, 378, 192]
# 2  [16, 80, 185, 327, 491, 502, 126, 164, 333, 13...
# 3  [355, 331, 301, 317, 322, 165, 244, 152, 415, ...
# 4  [380, 89, 192, 102, 210, 394, 254, 403, 8, 443...
#
#                                           checkpoint              task  \
# 0  /home/hgf_hmgu/hgf_gib4562/tdmpc2/ckpts/cartpo...  cartpole-swingup
# 1  /home/hgf_hmgu/hgf_gib4562/tdmpc2/ckpts/cartpo...  cartpole-swingup
# 2  /home/hgf_hmgu/hgf_gib4562/tdmpc2/ckpts/cartpo...  cartpole-swingup
# 3  /home/hgf_hmgu/hgf_gib4562/tdmpc2/ckpts/cartpo...  cartpole-swingup
# 4  /home/hgf_hmgu/hgf_gib4562/tdmpc2/ckpts/cartpo...  cartpole-swingup
#
#    latent_dim  episode_idx  episode_length  total_reward  \
# 0         512            0             500    769.784071
# 1         512            0             500    894.339316
# 2         512            0             500    734.485539
# 3         512            0             500    909.194063
# 4         512            0             500    360.119539
#
#                     timestamp obs_type  \
# 0  2025-11-11T19:30:09.036350    state
# 1  2025-11-11T20:15:40.630947    state
# 2  2025-11-11T20:50:39.751113    state
# 3  2025-11-11T21:00:58.615257    state
# 4  2025-11-12T00:37:14.211185    state
#
#                                            directory  config_scale
# 0  /home/hgf_hmgu/hgf_gib4562/tdmpc2/logs/latent_...           NaN
# 1  /home/hgf_hmgu/hgf_gib4562/tdmpc2/logs/latent_...           0.1
# 2  /home/hgf_hmgu/hgf_gib4562/tdmpc2/logs/latent_...           0.1
# 3  /home/hgf_hmgu/hgf_gib4562/tdmpc2/logs/latent_...           0.1
# 4  /home/hgf_hmgu/hgf_gib4562/tdmpc2/logs/latent_...           1.0

# %%
import pickle


def load_intervention_data(df_metadata,
                           type=None,
                           num_dims=None,
                           hinge_1_value=None,
                           seed=None,
                           scale=None):
    """
    Load intervention data from directories matching the specified criteria.
    
    Parameters can be single values or lists. If a parameter is None, it matches all values.
    
    Returns:
        pd.DataFrame: DataFrame with config info and episode data
    """

    # Convert single values to lists for uniform handling
    def to_list(val):
        if val is None:
            return None
        return val if isinstance(val, list) else [val]

    type_list = to_list(type)
    num_dims_list = to_list(num_dims)
    hinge_1_value_list = to_list(hinge_1_value)
    seed_list = to_list(seed)
    scale_list = to_list(scale)

    # Filter configs based on criteria
    filtered_configs = []
    for idx, config in df_metadata.iterrows():
        # Check each criterion
        if type_list is not None and config.get('config_type') not in type_list:
            continue
        if num_dims_list is not None and config.get(
                'config_num_dims') not in num_dims_list:
            continue
        if hinge_1_value_list is not None and config.get(
                'config_hinge_1_value') not in hinge_1_value_list:
            continue
        if seed_list is not None and config.get('config_seed') not in seed_list:
            continue
        if scale_list is not None and config.get(
                'config_scale') not in scale_list:
            continue

        filtered_configs.append(config)

    print(f"Found {len(filtered_configs)} configurations")
    # Load episode data for each matching config
    results = []
    for config in filtered_configs:
        directory = Path(config['directory'])
        episode_path = directory / "activations" / "episode_0000.pkl"

        if episode_path.exists() and metadata_path.exists():
            # Load the pickled episode data
            with open(episode_path, 'rb') as f:
                episode_data = pickle.load(f)

            # Unflatten the data structure
            episode_data = episode_data['data']
            for key, value in episode_data.items():

                if key == 'latent_states':
                    config[key] = value.squeeze()
                else:
                    config[key] = value

            results.append(config)

    return pd.DataFrame(results)

# %%
df_ablation = load_intervention_data(df_metadata,
                                     type=['ablation'],
                                     num_dims=[0, 10, 50, 100, 200, 300, 400],
                                     hinge_1_value=None,
                                     seed=[1, 2, 3, 4, 5])
# Out:
# Found 315 configurations

# %%
df_noise = load_intervention_data(df_metadata, type=['noise'])
#num_dims=[0, 10, 50, 100, 200, 300, 400],
#hinge_1_value=None,
#seed=[1, 2, 3, 4, 5])
# Out:
# Found 945 configurations

# %%
fig, ax = plt.subplots(figsize=(10, 6))
scatter = ax.scatter(df_ablation['config_num_dims'],
                     df_ablation['total_reward'],
                     c=df_ablation['config_hinge_1_value'],
                     cmap='viridis',
                     alpha=0.6,
                     s=50,
                     edgecolors='black',
                     linewidth=0.5)
cbar = plt.colorbar(scatter, ax=ax, label='Pole angle starting position')
ax.set_xlabel('Number of Dimensions Ablated', fontsize=12)
ax.set_ylabel('Total Reward', fontsize=12)
ax.set_title('Effect of Latent Dimension Ablation on Task Performance',
             fontsize=13,
             pad=15)
ax.grid(True, alpha=0.3, linestyle='--', linewidth=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.ylim(None, 1000)
plt.show()

# %%
df_noise.keys()
# Out:
# Index(['config_id', 'config_type', 'config_location', 'config_num_dims',
#        'config_hinge_1_value', 'config_seed', 'dims_affected', 'checkpoint',
#        'task', 'latent_dim', 'episode_idx', 'episode_length', 'total_reward',
#        'timestamp', 'obs_type', 'directory', 'config_scale', 'observations',
#        'actions', 'rewards', 'dones', 'latent_states', 'timesteps'],
#       dtype='object')

# %%
hinge1values = df_metadata['config_hinge_1_value'].unique()

# %%
hinge1values
# Out:
# array([ 2.32, -2.73,  1.5 , -2.32, -1.91,  2.73, -1.5 ,  3.14,  1.91])

# %%
fig, ax = plt.subplots(figsize=(10, 6))

# Add jitter to x-axis to avoid overlapping points
jitter_amount = 5  # Adjust this value to control the amount of jitter
x_jittered = df_noise['config_num_dims'] + np.random.uniform(
    -jitter_amount, jitter_amount, size=len(df_noise))

scatter = ax.scatter(x_jittered,
                     df_noise['total_reward'],
                     c=df_noise['config_scale'],
                     cmap='viridis',
                     alpha=0.6,
                     s=50,
                     edgecolors='black',
                     linewidth=0.5)
cbar = plt.colorbar(scatter, ax=ax, label='Noise Scale')
ax.set_xlabel('Number of Dimensions with Noise', fontsize=12)
ax.set_ylabel('Total Reward', fontsize=12)
ax.set_title('Effect of Latent Dimension Noise on Task Performance',
             fontsize=13,
             pad=15)
ax.grid(True, alpha=0.3, linestyle='--', linewidth=0.5)
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
plt.tight_layout()
plt.ylim(None, 1000)
plt.show()

# %%
df_noise = load_intervention_data(df_metadata, type=['noise'])

# %%
# Get unique scales and hinge values
scales = sorted(df_noise['config_scale'].unique())
hinge_values = sorted(df_noise['config_hinge_1_value'].unique())

# Create a colormap from dark red to light red
import matplotlib.colors as mcolors

n_hinges = len(hinge_values)
colors = [
    mcolors.to_hex((0.9, i / (n_hinges - 1), i / (n_hinges - 1)))
    for i in range(n_hinges)
]

# Create a separate plot for each scale
for scale in scales:
    df_scale = df_noise[df_noise['config_scale'] == scale]

    fig, ax = plt.subplots(figsize=(10, 6))

    # Plot one line per hinge value
    for idx, hinge_val in enumerate(hinge_values):
        df_hinge = df_scale[df_scale['config_hinge_1_value'] == hinge_val]

        # Group by num_dims and compute mean across seeds
        mean_rewards = df_hinge.groupby(
            'config_num_dims')['total_reward'].mean()

        ax.plot(mean_rewards.index,
                mean_rewards.values,
                marker='o',
                label=f'Hinge={hinge_val:.2f}',
                linewidth=2,
                markersize=6,
                color=colors[idx])

    ax.set_xlabel('Number of Dimensions with Noise', fontsize=12)
    ax.set_ylabel('Total Reward (Mean)', fontsize=12)
    ax.set_title(f'Effect of Latent Dimension Noise (Scale={scale})',
                 fontsize=13,
                 pad=15)
    ax.legend(title='Hinge Value', fontsize=10)
    ax.grid(True, alpha=0.3, linestyle='--', linewidth=0.5)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    plt.tight_layout()
    plt.ylim(None, 1000)
    plt.show()

# %%
# Get unique scales and hinge values
scales = sorted(df_noise['config_scale'].unique())
hinge_values = sorted(df_noise['config_hinge_1_value'].unique())

# Create a colormap for scales
import matplotlib.colors as mcolors

n_scales = len(scales)
# colors = [
#     mcolors.to_hex((i / (n_scales - 1), 0.2, 0.9 - i / (n_scales - 1)))
#     for i in range(n_scales)
# ]

# Create a grid of subplots with 3 plots per row, sharing y-axis
n_hinge_values = len(hinge_values)
n_cols = 3
n_rows = (n_hinge_values + n_cols - 1) // n_cols  # Ceiling division

fig, axes = plt.subplots(n_rows, n_cols, figsize=(15, 5 * n_rows), sharey=True)

# Flatten axes array for easier iteration
if n_rows == 1:
    axes = axes.reshape(1, -1)
axes_flat = axes.flatten()

# Plot each hinge value in a separate subplot
for plot_idx, hinge_val in enumerate(hinge_values):
    df_hinge = df_noise[df_noise['config_hinge_1_value'] == hinge_val]

    ax = axes_flat[plot_idx]

    # Plot one line per scale
    for idx, scale in enumerate(scales):
        df_scale = df_hinge[df_hinge['config_scale'] == scale]

        # Group by num_dims and compute mean across seeds
        mean_rewards = df_scale.groupby(
            'config_num_dims')['total_reward'].mean()

        ax.plot(mean_rewards.index,
                mean_rewards.values,
                marker='o',
                label=f'Scale={scale}',
                linewidth=2,
                markersize=6)

    ax.set_xlabel('Number of Dimensions with Noise', fontsize=12)
    if plot_idx % n_cols == 0:  # Only set ylabel for leftmost plots
        ax.set_ylabel('Total Reward (Mean)', fontsize=12)
    ax.set_title(f'Hinge={hinge_val:.2f}', fontsize=13, pad=15)
    ax.legend(title='Scale', fontsize=10)
    ax.grid(True, alpha=0.3, linestyle='--', linewidth=0.5)
    ax.spines['top'].set_visible(False)
    ax.spines['right'].set_visible(False)
    ax.set_ylim(None, 1000)

# Hide any unused subplots
for plot_idx in range(n_hinge_values, len(axes_flat)):
    axes_flat[plot_idx].set_visible(False)

plt.tight_layout()
plt.show()

# %%
# df_plot = df_noise[(df_noise['config_num_dims'] == 400) &
#                    (df_noise['config_scale'] == 0.1) &
#                    (df_noise['config_hinge_1_value'] == -2.73) &
#                    (df_noise['config_seed'] == 1)]
# latents = df_plot['latent_states'].iloc[0].T

df_plot = df_ablation[(df_ablation['config_num_dims'] == 300) &
                      (df_ablation['config_hinge_1_value'] == -2.73) &
                      (df_ablation['config_seed'] == 1)]
latents = df_plot['latent_states'].iloc[0].T

# %%
model, y, isort, X_embedding = fit_rastermap(latents,
                                             n_PCs=200,
                                             n_clusters=100,
                                             locality=0.75,
                                             time_lag_window=10)
# Out:
# 2025-11-12 15:28:45,121 [INFO] normalizing data across axis=1
# 2025-11-12 15:28:45,125 [INFO] projecting out mean along axis=0
# 2025-11-12 15:28:45,127 [INFO] data normalized, 0.01sec
# 2025-11-12 15:28:45,127 [INFO] sorting activity: 212 valid samples by 500 timepoints
# 2025-11-12 15:28:45,150 [INFO] n_PCs = 200 computed, 0.03sec
# 2025-11-12 15:28:45,199 [INFO] 100 clusters computed, time 0.08sec
# /home/hgf_hmgu/hgf_gib4562/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/rastermap/rastermap.py:278: RuntimeWarning: invalid value encountered in divide
#   X /= stdx[:,np.newaxis]
# 2025-11-12 15:29:42,400 [INFO] clusters sorted, time 57.28sec
# 2025-11-12 15:29:42,442 [INFO] clusters upsampled, time 57.32sec
# 2025-11-12 15:29:42,446 [INFO] rastermap complete, time 57.32sec

# %%
plot_rastermap_with_rewards_actions(X_embedding,
                                    isort,
                                    df_plot.iloc[0]['rewards'],
                                    df_plot.iloc[0]['actions'],
                                    latents=latents,
                                    plot_type='latents',
                                    sort_latents=True)

# %%
plot_rastermap_with_rewards_actions(X_embedding=None,
                                    isort=None,
                                    rewards=df_plot.iloc[0]['rewards'],
                                    actions=df_plot.iloc[0]['actions'],
                                    latents=latents,
                                    plot_type='latents',
                                    sort_latents=False)

# %% [markdown]
# ## Non-basis aligned subspaces

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA, FastICA, SparsePCA
from sklearn.preprocessing import StandardScaler


def analyze_latent_to_observation_mapping(observations,
                                          latents,
                                          method="pca",
                                          n_components=10,
                                          obs_labels=None):
    """
    observations: [T, D_obs]  -> e.g. DMControl proprioceptive states
    latents: [T, D_latent]    -> TD-MPC2 encoder outputs
    method: 'pca' or 'ica'
    obs_labels: optional list of observation names
    """
    # normalize latents for analysis
    Z = StandardScaler().fit_transform(latents)
    O = StandardScaler().fit_transform(observations)

    if method == "pca":
        model = PCA(n_components=n_components)
    elif method == "ica":
        model = FastICA(n_components=n_components, whiten="unit-variance")
    elif method == 'sparse_pca':
        model = SparsePCA(n_components=n_components, alpha=0.1)
    else:
        raise ValueError("method must be 'pca' or 'ica'")

    # Fit decomposition
    F = model.fit_transform(Z)  # [T, n_components]
    comps = model.components_  # [n_components, D_latent]

    # Correlate each component with each observation variable
    corr_matrix = np.corrcoef(F.T, O.T)[:n_components, n_components:]

    # Get explained variance if available
    explained_variance = None
    if hasattr(model, 'explained_variance_ratio_'):
        explained_variance = model.explained_variance_ratio_
        print(f"Explained variance by component: {explained_variance}")
        print(f"Total explained variance: {explained_variance.sum():.3f}")

    return corr_matrix, comps, explained_variance


def plot_component_correlations(corr_matrix,
                                obs_labels=None,
                                title="Latent-Observation Map"):
    n_components, D_obs = corr_matrix.shape
    plt.figure(figsize=(12, 4))
    plt.imshow(corr_matrix, aspect='auto', cmap='coolwarm', vmin=-1, vmax=1)
    plt.colorbar(label='Correlation')
    plt.xlabel("Observation variables")
    plt.ylabel("Latent components")
    plt.title(title)
    if obs_labels:
        plt.xticks(range(D_obs), obs_labels, rotation=90)
    plt.tight_layout()
    plt.show()

# %%
df_plot = df_ablation[(df_ablation['config_num_dims'] == 0) &
                      (df_ablation['config_hinge_1_value'] == -2.73) &
                      (df_ablation['config_seed'] == 1)]
latents = df_plot['latent_states'].iloc[0]
obs = np.array(df_plot['observations'].iloc[0])
rewards = df_plot['rewards'].iloc[0]
actions = df_plot['actions'].iloc[0]
y_vars = np.concatenate([obs, rewards[..., None], actions], axis=1)

# %%
corr_pca, comps_pca, exp_var = analyze_latent_to_observation_mapping(
    y_vars, latents, method="pca", n_components=4)
plot_component_correlations(abs(corr_pca),
                            obs_labels=None,
                            title="PCA alignment map")
# Out:
# Explained variance by component: [0.38269228 0.1816769  0.15119427 0.11369837]
# Total explained variance: 0.829

# %%
exp_var

# %%
import numpy as np

# comps: np.array shape (n_components, D_z) from PCA/ICA
i = 1  # index of component you want to test
w = comps_pca[i].astype(float)
w = w / np.linalg.norm(w)  # unit-norm direction

# top-k contributing latent neurons (by absolute weight)
k = 10

top_idx = np.argsort(np.abs(w))[-k:][::-1]
print("Top contributing latent dims:", top_idx)
print("Weights:", w[top_idx])
# Out:
# Top contributing latent dims: [445 174 214  58  28  60   6 151 436 315]
# Weights: [ 0.09774776  0.09637587  0.0952351  -0.0930297   0.08973535  0.08962917
#   0.088489   -0.0876828   0.08688286  0.08671288]

# %%
plt.figure(figsize=(12, 4))
plt.stem(abs(w))
plt.xlabel('Latent dimension')
plt.ylabel('Weight')
plt.title('PCA Component Weights')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Plot PCA components in 2D
plt.figure(figsize=(12, 4))
plt.subplot(1, 2, 1)
plt.scatter(comps_pca[0, :], comps_pca[1, :], alpha=0.5)
plt.xlabel('PC1 weights')
plt.ylabel('PC2 weights')
plt.title('PCA Component Weights')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.scatter(comps_pca[0, :], comps_pca[1, :], alpha=0.5)
plt.xlabel('PC1 weights')
plt.ylabel('PC2 weights')
plt.title('PCA Component Weights')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
corr_pca, _ = analyze_latent_to_observation_mapping(obs,
                                                    latents,
                                                    method="pca",
                                                    n_components=30)
plot_component_correlations(abs(corr_pca),
                            obs_labels=None,
                            title="PCA alignment map")

# %%
corr_pca, _ = analyze_latent_to_observation_mapping(obs,
                                                    latents,
                                                    method="ica",
                                                    n_components=3)
plot_component_correlations(abs(corr_pca),
                            obs_labels=None,
                            title="ICA alignment map")

# %% [markdown]
# ## Reconstruct cartpole video

# %%
# reconstruct_cartpole_dmcontrol.py
import numpy as np
import imageio
from dm_control import suite
from dm_control import mujoco
import os


def reconstruct_cartpole_video(states,
                               out_path="cartpole_reconstruction.mp4",
                               fps=30,
                               domain="cartpole",
                               task="swingup"):
    """
    Reconstructs a dm_control cartpole video from saved observation states.
    
    Args:
        states: np.ndarray of shape (T, d), typically columns are:
                [cart_pos, pole_angle, cart_vel, pole_ang_vel]
        out_path: output video file
        fps: frames per second for video
        domain/task: dm_control domain and task name
    """
    env = suite.load(domain, task)
    physics = env.physics
    frames = []

    # --- identify relevant dofs
    # CartPole has qpos: [x, theta]
    # and qvel: [x_dot, theta_dot]
    T, d = states.shape
    assert d >= 4, "Expected at least 4 dims: [x, theta, x_dot, theta_dot]"

    for t in range(T):
        qpos = states[t, :3]  # [x, theta]
        qvel = states[t, 3:5]  # [x_dot, theta_dot]
        physics.data.qpos[:] = qpos
        physics.data.qvel[:] = qvel
        physics.forward()  # propagate to update geometry

        # Render frame at reasonable resolution
        frame = physics.render(height=240, width=320, camera_id=0)
        frames.append(frame)

    # write video
    imageio.mimwrite(out_path, frames, fps=fps, macro_block_size=None)
    print(f"Wrote {len(frames)} frames to {os.path.abspath(out_path)}")


# Example usage:
# states = np.load("cartpole_states.npy")  # shape (T, 4)
# Out:
# 2025-11-11 17:53:12,007 [INFO] MUJOCO_GL is not set, so an OpenGL backend will be chosen automatically.
# 2025-11-11 17:53:12,129 [INFO] Successfully imported OpenGL backend: glfw
# /home/hgf_hmgu/hgf_gib4562/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/glfw/__init__.py:914: GLFWError: (65544) b'X11: The DISPLAY environment variable is missing'
#   warnings.warn(message, GLFWError)
# 2025-11-11 17:53:12,395 [INFO] MuJoCo library version is: 3.1.2

# %%
states = np.array(df_outlier.iloc[0]['data']['observations'])
reconstruct_cartpole_video(states, "cartpole_dmcontrol.mp4", fps=30)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[31], line 2
#       1 states = np.array(df_outlier.iloc[0]['data']['observations'])
# ----> 2 reconstruct_cartpole_video(states, "cartpole_dmcontrol.mp4", fps=30)
#
# Cell In[30], line 37, in reconstruct_cartpole_video(states, out_path, fps, domain, task)
#      35 qpos = states[t, :3]  # [x, theta]
#      36 qvel = states[t, 3:5]  # [x_dot, theta_dot]
# ---> 37 physics.data.qpos[:] = qpos
#      38 physics.data.qvel[:] = qvel
#      39 physics.forward()  # propagate to update geometry
#
# ValueError: could not broadcast input array from shape (3,) into shape (2,)

# %%
env = suite.load("cartpole", "swingup")
env.physics.data.qpos[:] = states[0, :2]
env.physics.data.qvel[:] = states[0, 2:4]
env.physics.forward()
frame = env.physics.render(height=240, width=320, camera_id=0)
plt.imshow(frame)
plt.show()
# Out:
# /home/hgf_hmgu/hgf_gib4562/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/glfw/__init__.py:914: GLFWError: (65537) b'The GLFW library is not initialized'
#   warnings.warn(message, GLFWError)
# ---------------------------------------------------------------------------
# FatalError                                Traceback (most recent call last)
# Cell In[38], line 5
#       3 env.physics.data.qvel[:] = states[0, 2:4]
#       4 env.physics.forward()
# ----> 5 frame = env.physics.render(height=240, width=320, camera_id=0)
#       6 plt.imshow(frame)
#       7 plt.show()
#
# File ~/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/dm_control/mujoco/engine.py:223, in Physics.render(self, height, width, camera_id, overlays, depth, segmentation, scene_option, render_flag_overrides, scene_callback)
#     178 def render(
#     179     self,
#     180     height=240,
#    (...)
#     189                                       None]] = None,
#     190 ):
#     191   """Returns a camera view as a NumPy array of pixel values.
#     192
#     193   Args:
#    (...)
#     221     The rendered RGB, depth or segmentation image.
#     222   """
# --> 223   camera = Camera(
#     224       physics=self,
#     225       height=height,
#     226       width=width,
#     227       camera_id=camera_id,
#     228       scene_callback=scene_callback)
#     229   image = camera.render(
#     230       overlays=overlays, depth=depth, segmentation=segmentation,
#     231       scene_option=scene_option, render_flag_overrides=render_flag_overrides)
#     232   camera._scene.free()  # pylint: disable=protected-access
#
# File ~/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/dm_control/mujoco/engine.py:711, in Camera.__init__(self, physics, height, width, camera_id, max_geom, scene_callback)
#     708 self._rgb_buffer = np.empty((self._height, self._width, 3), dtype=np.uint8)
#     709 self._depth_buffer = np.empty((self._height, self._width), dtype=np.float32)
# --> 711 if self._physics.contexts.mujoco is not None:
#     712   with self._physics.contexts.gl.make_current() as ctx:
#     713     ctx.call(mujoco.mjr_setBuffer, mujoco.mjtFramebuffer.mjFB_OFFSCREEN,
#     714              self._physics.contexts.mujoco.ptr)
#
# File ~/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/dm_control/mujoco/engine.py:533, in Physics.contexts(self)
#     531 with self._contexts_lock:
#     532   if not self._contexts:
# --> 533     self._make_rendering_contexts()
#     534 return self._contexts
#
# File ~/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/dm_control/mujoco/engine.py:519, in Physics._make_rendering_contexts(self)
#     516 render_context = _render.Renderer(
#     517     max_width=max_width, max_height=max_height)
#     518 # Create the MuJoCo context.
# --> 519 mujoco_context = wrapper.MjrContext(self.model, render_context)
#     520 self._contexts = Contexts(gl=render_context, mujoco=mujoco_context)
#
# File ~/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/dm_control/mujoco/wrapper/core.py:608, in MjrContext.__init__(self, model, gl_context, font_scale)
#     606 self._gl_context = gl_context
#     607 with gl_context.make_current() as ctx:
# --> 608   ptr = ctx.call(mujoco.MjrContext, model.ptr, font_scale)
#     609   ctx.call(mujoco.mjr_setBuffer, mujoco.mjtFramebuffer.mjFB_OFFSCREEN, ptr)
#     610 gl_context.keep_alive(ptr)
#
# File ~/miniconda3/envs/tdmpc2/lib/python3.9/site-packages/dm_control/_render/executor/render_executor.py:138, in PassthroughRenderExecutor.call(self, func, *args, **kwargs)
#     136 def call(self, func, *args, **kwargs):
#     137   self._check_locked()
# --> 138   return func(*args, **kwargs)
#
# FatalError: an OpenGL platform library has not been loaded into this process, this most likely means that a valid OpenGL context has not been created before mjr_makeContext was called

# %%
env.physics.data.qpos
# Out:
# array([0., 0.])

# %%
env.physics.data.qvel
# Out:
# array([0., 0.])
